# %%
import pandas as pd

# %%
import sys
sys.path.append('../../')
from consensus_variables import *

# %%
site_selection = pd.read_csv(f'{deepcsa_run_dir}/sitecomparisongloballoc/all_samples.global_loc.site.comparison.tsv.gz', sep='\t')
site_selection = site_selection[site_selection['GENE'].isin(gene_order)]

# %%
post_process_vep_panel = pd.read_csv(f'{deepcsa_run_dir}/postprocessveppanel/captured_panel.tab.compact_rich.tsv', sep='\t')
post_process_vep_panel
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 post_process_vep_panel = pd.read_csv(f'{deepcsa_run_dir}/postprocessveppanel/captured_panel.tab.compact_rich.tsv', sep='\t')
#       2 post_process_vep_panel
#
# File ~/miniforge3/envs/notebooks_env/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/miniforge3/envs/notebooks_env/lib/python3.10/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/miniforge3/envs/notebooks_env/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/miniforge3/envs/notebooks_env/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/miniforge3/envs/notebooks_env/lib/python3.10/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/data/bbg/nobackup/bladder_ts/bladder_paper_data/deepCSA_outputs/postprocessveppanel/captured_panel.tab.compact_rich.tsv'

# %%
top_site_sel = site_selection[site_selection["p_value"] < 1e-5].sort_values(by = 'OBS/EXP', ascending = False).head(200)

# %%
top_site_sel.merge(post_process_vep_panel, how = 'left').head(60)[['GENE', 'OBSERVED_MUTS', 'OBS/EXP',
                                                                    'MUT_ID', 'STRAND', 'IMPACT',
                                                                    'Protein_position', 'Amino_acids', 'CONTEXT_MUT']]
# Out:
#       GENE  OBSERVED_MUTS      OBS/EXP              MUT_ID  STRAND  \
# 0    RBM10           45.0  1532.113084   chrX_47186056_A/G       1
# 1    KDM6A            8.0  1437.844247   chrX_45034989_A/T       1
# 2    EP300           20.0  1237.345360  chr22_41176250_T/G       1
# 3    STAG2           28.0   992.859451  chrX_124042561_A/G       1
# 4    KDM6A            6.0   971.460694   chrX_45079158_T/C       1
# 5    EP300           22.0   920.068761  chr22_41169526_A/G       1
# 6    RBM10           11.0   712.974214   chrX_47179895_A/T       1
# 7    KDM6A            5.0   696.727425   chrX_45083602_A/C       1
# 8    KDM6A            9.0   689.290406   chrX_45083449_T/G       1
# 9   CREBBP           17.0   674.121742   chr16_3736794_C/A      -1
# 10   KDM6A            3.0   671.173865   chrX_45061310_T/G       1
# 11   KDM6A            5.0   656.615240   chrX_45079129_T/G       1
# 12   KDM6A            6.0   654.176940   chrX_45090867_A/C       1
# 13   EP300            7.0   621.325515  chr22_41169493_T/G       1
# 14   KMT2D           19.0   620.734192  chr12_49032064_A/C      -1
# 15   EP300           48.0   604.454632  chr22_41169571_A/G       1
# 16   KDM6A            2.0   601.752675   chrX_45076695_A/T       1
# 17   KDM6A            5.0   596.413893   chrX_45089904_T/A       1
# 18   KDM6A           30.0   558.024157   chrX_45110078_G/A       1
# 59   EP300           10.0   346.428609  chr22_41170483_A/G       1
#
#                    IMPACT Protein_position Amino_acids CONTEXT_MUT
# 0   splice_region_variant                -           -       TTT>C
# 1   splice_region_variant                -           -       CTT>A
# 2                missense             1595         F/V       CTT>G
# 3   splice_region_variant                -           -       TTT>C
# 4                missense             1036         F/S       TTC>C
# 5                missense             1399         D/G       ATC>C
# 6                missense              306         N/I       GTT>A
# 7                missense             1195         T/P       GTT>G
# 8   splice_region_variant                -           -       ATT>G
# 9                missense             1472         W/C       CCC>A
# 10  splice_region_variant                -           -       ATC>G
# 11  splice_region_variant                -           -       ATT>G
# 12  splice_region_variant                -           -       TTA>G
# 13  splice_region_variant                -           -       ATT>G
# 14               nonsense             4214         L/*       TTA>G
# 15               missense             1414         Y/C       ATA>C
# 16       essential_splice                -           -       CTG>A
# 17               missense             1289         I/N       ATT>A
# 18       essential_splice                -           -       CCT>T
# 19               missense             1435         D/G       ATC>C
# 20               missense             1163         R/P       ACG>G
# 21               missense              360         F/S       TTC>C
# 22               missense             1440         P/R       CCA>G
# 23               missense             1491         Q/P       TTG>G
# 24               missense             1436         W/S       CCA>G
# 25               missense             1415         H/P       ATG>G
# 26               missense             1373         F/C       TTC>G
# 27               missense             1273         N/Y       TTT>A
# 28  splice_region_variant                -           -       TTC>G
# 29               missense             1458         P/R       CCC>G
# 30               missense             1410         R/W       CTC>A
# 31               missense             1437         I/F       ATA>A
# 32               missense             1499         L/R       CTG>G
# 33               missense             1607         K/Q       TTC>G
# 34       essential_splice                -           -       CTA>A
# 35               missense             1158         L/R       CTT>G
# 36               missense             1400         S/R       GTG>G
# 37               missense             1446         R/G       CCG>G
# 38               missense             1472         W/R       CTG>A
# 39               missense             2196         Q/L       CTG>A
# 40               missense             1170         L/R       CTT>G
# 41               missense             1434         H/R       ATG>C
# 42               missense             1584         L/R       CTA>G
# 43               missense             1410         R/G       CTC>C
# 44               missense             1379         Q/R       TTG>C
# 45  splice_region_variant                -           -       TTT>C
# 46               missense             1910         Q/P       TTG>G
# 47               missense             1466         W/C       ACC>G
# 48       essential_splice                -           -       CTG>C
# 49               missense             1485         D/V       ATC>A
# 50  splice_region_variant                -           -       ATT>G
# 51               missense             1413         V/D       GTC>A
# 52  splice_region_variant                -           -       ATT>C
# 53               missense             1300         Q/R       CTG>C
# 54       essential_splice                -           -       CTA>A
# 55               missense             5404         S/F       TCC>T
# 56               missense             4794         K/R       CTT>C
# 57  splice_region_variant                -           -       ATT>G
# 58  splice_region_variant              192           Q       CCT>T
# 59               missense             1455         Q/R       CTG>C
