# %% [markdown]
# # Extended figure 4

# %%
import pandas as pd
import os, sys
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.patches import Patch

# %%
import sys
sys.path.append('../../')
from consensus_variables import *

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Load all methods data

# %%
gene_order = panel_no_hotspots

# %% [markdown]
# ### Omega

# %%
omega_file = f"{deepcsa_run_dir}/omega/output_mle.all_samples.tsv"
omega_data = pd.read_table(omega_file)
omega_data = omega_data[omega_data["impact"].isin(['missense', 'truncating'])]
omega_data = omega_data[omega_data["gene"].isin(gene_order)].reset_index(drop = True)
omega_data.head(10)
# Out:
#      gene       sample      impact  mutations       dnds  pvalue      lower  \
# 0  CREBBP  all_samples    missense       1630   2.786035     0.0   2.555603
# 1  CREBBP  all_samples  truncating        400   5.152344     0.0   4.436107
# 2  ARID1A  all_samples    missense       1234   1.528125     0.0   1.393955
# 3  ARID1A  all_samples  truncating       1850  15.885156     0.0  14.205010
# 4  CDKN1A  all_samples    missense        239   2.403125     0.0   2.054907
# 5  CDKN1A  all_samples  truncating        193  14.077344     0.0  11.638054
# 6   KMT2C  all_samples    missense        564   1.416797     0.0   1.264989
# 7   KMT2C  all_samples  truncating        163   2.973047     0.0   2.401561
# 8    TP53  all_samples    missense        559   5.210742     0.0   4.648260
# 9    TP53  all_samples  truncating         68   4.061719     0.0   3.082421
#
#        upper
# 0   3.038110
# 1   5.979370
# 2   1.676440
# 3  17.779688
# 4   2.803516
# 5  16.976514
# 6   1.586475
# 7   3.664575
# 8   5.833911
# 9   5.275708

# %%
omega_truncating = omega_data[omega_data["impact"] == "truncating"].reset_index(drop = True)[["gene", "dnds", "pvalue", "lower", "upper"]]
omega_truncating.columns = ["GENE", "omega_trunc", "pvalue", "lower", "upper"]


omega_missense = omega_data[omega_data["impact"] == "missense"].reset_index(drop = True)[["gene", "dnds", "pvalue", "lower", "upper"]]
omega_missense.columns = ["GENE", "omega_mis", "pvalue", "lower", "upper"]
omega_missense
# Out:
#       GENE  omega_mis    pvalue     lower     upper
# 0   CREBBP   2.786035  0.000000  2.555603  3.038110
# 1   ARID1A   1.528125  0.000000  1.393955  1.676440
# 2   CDKN1A   2.403125  0.000000  2.054907  2.803516
# 3    KMT2C   1.416797  0.000000  1.264989  1.586475
# 4     TP53   5.210742  0.000000  4.648260  5.833911
# 5    RBM10   3.303516  0.000000  2.990728  3.648364
# 6   NOTCH2   2.533594  0.000000  2.319187  2.769189
# 7    STAG2   1.763257  0.000000  1.577487  1.969556
# 8      RB1   1.718750  0.000000  1.473451  1.997681
# 9    FGFR3   0.881250  0.208065  0.718741  1.071069
# 10   KDM6A   4.072266  0.000000  3.696387  4.486694
# 11   KMT2D   1.864060  0.000000  1.729170  2.011765
# 12   FOXQ1   2.528905  0.000000  2.225726  2.870091
# 13   EP300   2.996875  0.000000  2.755504  3.259937

# %% [markdown]
# ### Omega multi

# %%
omega_file = f"{deepcsa_run_dir}/omega/output_mle.all_samples.multi.tsv"
omega_data_multi = pd.read_table(omega_file)
omega_data_multi = omega_data_multi[omega_data_multi["impact"].isin(['missense', 'truncating'])]
omega_data_multi = omega_data_multi[omega_data_multi["gene"].isin(gene_order)].reset_index(drop = True)
omega_data_multi.head(10)
# Out:
#      gene       sample      impact  mutations       dnds  pvalue      lower  \
# 0   KDM6A  all_samples    missense       1341   4.861719     0.0   4.444774
# 1   KDM6A  all_samples  truncating       2836  51.860938     0.0  47.171599
# 2  CREBBP  all_samples    missense       2768   5.251563     0.0   4.857422
# 3  CREBBP  all_samples  truncating        555   6.660938     0.0   5.810085
# 4  NOTCH2  all_samples    missense       1857   3.137402     0.0   2.884675
# 5  NOTCH2  all_samples  truncating        377   6.193750     0.0   5.330199
# 6   FOXQ1  all_samples    missense        802   3.457129     0.0   3.102822
# 7   FOXQ1  all_samples  truncating         91   3.272253     0.0   2.477398
# 8  ARID1A  all_samples    missense       1545   1.694922     0.0   1.552592
# 9  ARID1A  all_samples  truncating       2700  20.637488     0.0  18.596646
#
#        upper
# 0   5.317651
# 1  57.048926
# 2   5.681250
# 3   7.636279
# 4   3.416333
# 5   7.181909
# 6   3.850195
# 7   4.287268
# 8   1.852393
# 9  22.934241

# %%
omega_truncating_multi = omega_data_multi[omega_data_multi["impact"] == "truncating"].reset_index(drop = True)[["gene", "dnds", "pvalue", "lower", "upper"]]
omega_truncating_multi.columns = ["GENE", "omega_trunc", "pvalue", "lower", "upper"]


omega_missense_multi = omega_data_multi[omega_data_multi["impact"] == "missense"].reset_index(drop = True)[["gene", "dnds", "pvalue", "lower", "upper"]]
omega_missense_multi.columns = ["GENE", "omega_mis", "pvalue", "lower", "upper"]
omega_missense_multi
# Out:
#       GENE  omega_mis    pvalue     lower     upper
# 0    KDM6A   4.861719  0.000000  4.444774  5.317651
# 1   CREBBP   5.251563  0.000000  4.857422  5.681250
# 2   NOTCH2   3.137402  0.000000  2.884675  3.416333
# 3    FOXQ1   3.457129  0.000000  3.102822  3.850195
# 4   ARID1A   1.694922  0.000000  1.552592  1.852393
# 5   CDKN1A   3.120313  0.000000  2.711021  3.584180
# 6     TP53   6.476563  0.000000  5.824538  7.196777
# 7    EP300   3.676367  0.000000  3.402464  3.974219
# 8    STAG2   1.870313  0.000000  1.683191  2.077222
# 9    FGFR3   1.001562  0.984109  0.834043  1.196265
# 10   KMT2D   1.991797  0.000000  1.851484  2.145605
# 11   RBM10   3.807813  0.000000  3.464748  4.187451
# 12   KMT2C   1.459375  0.000000  1.310050  1.624781
# 13     RB1   2.453125  0.000000  2.139384  2.802856

# %%
omega_missense_multi['multi'] = True
omega_missense['multi'] = False
omega_truncating_multi['multi'] = True
omega_truncating['multi'] = False

# %%
omega_missense_all = pd.concat((omega_missense, omega_missense_multi))
omega_truncating_all = pd.concat((omega_truncating, omega_truncating_multi))
omega_missense_all
# Out:
#       GENE  omega_mis    pvalue     lower     upper  multi
# 0   CREBBP   2.786035  0.000000  2.555603  3.038110  False
# 1   ARID1A   1.528125  0.000000  1.393955  1.676440  False
# 2   CDKN1A   2.403125  0.000000  2.054907  2.803516  False
# 3    KMT2C   1.416797  0.000000  1.264989  1.586475  False
# 4     TP53   5.210742  0.000000  4.648260  5.833911  False
# 5    RBM10   3.303516  0.000000  2.990728  3.648364  False
# 6   NOTCH2   2.533594  0.000000  2.319187  2.769189  False
# 7    STAG2   1.763257  0.000000  1.577487  1.969556  False
# 8      RB1   1.718750  0.000000  1.473451  1.997681  False
# 9    FGFR3   0.881250  0.208065  0.718741  1.071069  False
# 10   KDM6A   4.072266  0.000000  3.696387  4.486694  False
# 11   KMT2D   1.864060  0.000000  1.729170  2.011765  False
# 12   FOXQ1   2.528905  0.000000  2.225726  2.870091  False
# 13   EP300   2.996875  0.000000  2.755504  3.259937  False
# 0    KDM6A   4.861719  0.000000  4.444774  5.317651   True
# 1   CREBBP   5.251563  0.000000  4.857422  5.681250   True
# 2   NOTCH2   3.137402  0.000000  2.884675  3.416333   True
# 3    FOXQ1   3.457129  0.000000  3.102822  3.850195   True
# 4   ARID1A   1.694922  0.000000  1.552592  1.852393   True
# 5   CDKN1A   3.120313  0.000000  2.711021  3.584180   True
# 6     TP53   6.476563  0.000000  5.824538  7.196777   True
# 7    EP300   3.676367  0.000000  3.402464  3.974219   True
# 8    STAG2   1.870313  0.000000  1.683191  2.077222   True
# 9    FGFR3   1.001562  0.984109  0.834043  1.196265   True
# 10   KMT2D   1.991797  0.000000  1.851484  2.145605   True
# 11   RBM10   3.807813  0.000000  3.464748  4.187451   True
# 12   KMT2C   1.459375  0.000000  1.310050  1.624781   True
# 13     RB1   2.453125  0.000000  2.139384  2.802856   True

# %%
gene_order = list(omega_truncating.sort_values("omega_trunc", ascending= False)["GENE"].values)

# %%
pvalue_thres = 0.05

# %%
# fig, ax1 = plt.subplots(1, 1, figsize=(8, 5))

    
# # Separate data based on significance of p-value
# omega_truncating_sig = omega_truncating_all[omega_truncating_all["pvalue"] <= pvalue_thres].reset_index(drop = True)
# omega_truncating_notsig = omega_truncating_all[omega_truncating_all["pvalue"] > pvalue_thres].reset_index(drop = True)

# # Plot the second bar plot in the middle subplot
# sns.barplot(data=omega_truncating_notsig, x='GENE', y='omega_trunc',
#             ax=ax1, alpha=1,
#             fill = False,
#             hue = 'multi',
#             hue_order = [False, True],
#             # legend = False,
#             order = gene_order,
#             palette = {False : metrics_colors_dictionary["omega_trunc"],
#                        True : metrics_colors_dictionary["omega_trunc"]
#                       }
#                        )


# # Plot the second bar plot in the middle subplot
# sns.barplot(data=omega_truncating_sig, x='GENE', y='omega_trunc',
#             ax=ax1, alpha=1,
#             legend = False,
#             hue = 'multi',
#             hue_order = [False, True],
#             order = gene_order,
#             palette = {False : metrics_colors_dictionary["omega_trunc"],
#                        True : metrics_colors_dictionary["omega_trunc"]
#                       },
#             # color = metrics_colors_dictionary["omega_trunc"],
#             edgecolor = None
#            )

# sns.barplot(data=omega_truncating_all[omega_truncating_all['multi'] == True], x='GENE', y='omega_trunc',
#             ax=ax1, alpha=1,
#             fill = False,
#             hue = 'multi',
#             hue_order = [False, True],
#             order = gene_order,
#             palette = {False : metrics_colors_dictionary["omega_trunc"],
#                        True : metrics_colors_dictionary["omega_trunc"]
#                       },
#             dodge = True,
#             edgecolor = 'black',
#             hatch = '///'
#            )
# ax1.set_xlabel('')
# ax1.set_ylabel('dN/dS\ntruncating', fontsize = 12, rotation = 0, labelpad=7, verticalalignment = 'center',
#                horizontalalignment = 'right')
# ax1.set_yticks([0,5,10,15])
# ax1.set_yticklabels([0,5,10,15])
# ax1.set_xticklabels([])  # Hide x-axis labels on the middle plot
# ax1.axhline(1, color='black', linestyle='--')

# # Remove top and right spines
# ax1.spines['top'].set_visible(False)
# ax1.spines['right'].set_visible(False)
# ax1.set_xticks(range(len(gene_order)))
# ax1.set_xticklabels(gene_order, fontsize = 12, rotation=90)

# plt.show()

# %%
# Create the figure and subplots
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(2.5, 1.78), gridspec_kw={'height_ratios': [15, 3.3]})

# Separate data based on significance of p-value
omega_truncating_sig = omega_truncating_all[omega_truncating_all["pvalue"] <= pvalue_thres].reset_index(drop = True)
omega_truncating_notsig = omega_truncating_all[omega_truncating_all["pvalue"] > pvalue_thres].reset_index(drop = True)

# Plot the second bar plot in the middle subplot
sns.barplot(data=omega_truncating_notsig, x='GENE', y='omega_trunc',
            ax=ax1, alpha=1,
            fill = False,
            hue = 'multi',
            hue_order = [False, True],
            # legend = False,
            order = gene_order,
            palette = {False : metrics_colors_dictionary["omega_trunc"],
                       True : metrics_colors_dictionary["omega_trunc"]
                      }
                       )


# Plot the second bar plot in the middle subplot
sns.barplot(data=omega_truncating_sig, x='GENE', y='omega_trunc',
            ax=ax1, alpha=1,
            legend = False,
            hue = 'multi',
            hue_order = [False, True],
            order = gene_order,
            palette = {False : metrics_colors_dictionary["omega_trunc"],
                       True : metrics_colors_dictionary["omega_trunc"]
                      },
            # color = metrics_colors_dictionary["omega_trunc"],
            edgecolor = None
           )

sns.barplot(data=omega_truncating_all[omega_truncating_all['multi'] == True], x='GENE', y='omega_trunc',
            ax=ax1, alpha=1,
            fill = False,
            hue = 'multi',
            hue_order = [False, True],
            order = gene_order,
            palette = {False : metrics_colors_dictionary["omega_trunc"],
                       True : 'black'
                      },
            dodge = True,
            edgecolor = 'black',
            hatch = '///'
           )


ax1.set_xlabel('')
ax1.set_ylabel('dN/dS\ntruncating', fontsize = 12, rotation = 0, labelpad=7, verticalalignment = 'center',
               horizontalalignment = 'right')
ax1.set_yticks([0,5,10,15])
ax1.set_yticklabels([0,5,10,15])
ax1.set_xticklabels([])  # Hide x-axis labels on the middle plot
ax1.axhline(1, color='black', linestyle='--')

# Remove top and right spines
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.legend(frameon = False)



# Separate data based on significance of p-value
omega_missense_sig = omega_missense_all[omega_missense_all["pvalue"] <= pvalue_thres].reset_index(drop = True)
omega_missense_notsig = omega_missense_all[omega_missense_all["pvalue"] > pvalue_thres].reset_index(drop = True)

# Plot the second bar plot in the middle subplot
sns.barplot(data=omega_missense_notsig, x='GENE', y='omega_mis',
            ax=ax2, alpha=1,
            fill = False,
            hue = 'multi',
            hue_order = [False, True],
            legend = False,
            order = gene_order,
            palette = {False : metrics_colors_dictionary["omega_miss"],
                       True : metrics_colors_dictionary["omega_miss"]
                      }
           )


# Plot the second bar plot in the middle subplot
sns.barplot(data=omega_missense_sig, x='GENE', y='omega_mis',
            ax=ax2, alpha=1,
            hue = 'multi',
            hue_order = [False, True],
            legend = False,
            order = gene_order,
            palette = {False : metrics_colors_dictionary["omega_miss"],
                       True : metrics_colors_dictionary["omega_miss"]
                      },
            edgecolor = None
           )



sns.barplot(data=omega_missense_all[omega_missense_all['multi'] == True], x='GENE', y='omega_mis',
            ax=ax2, alpha=1,
            fill = False,
            hue = 'multi',
            hue_order = [False, True],
            order = gene_order,
            palette = {False : metrics_colors_dictionary["omega_miss"],
                       True : 'black'
                      },
            legend = False,
            dodge = True,
            edgecolor = 'black',
            hatch = '///'
           )

ax2.set_xlabel('')
ax2.set_ylabel('dN/dS\nmissense', fontsize = 12, rotation = 0, labelpad=7, verticalalignment = 'center',
               horizontalalignment = 'right')
ax2.set_yticks([0,2.5])
ax2.set_yticklabels([0,2.5])

ax2.set_xticklabels([])  # Hide x-axis labels on the upper plot
ax2.axhline(1, color='black', linestyle='--')
# Remove top and right spines
ax2.spines['top'].set_visible(False)
ax2.spines['right'].set_visible(False)

ax2.set_xticks(range(len(gene_order)))
ax2.set_xticklabels(gene_order, fontsize = 12, rotation=90)
plt.tight_layout()
plt.show()

# %%
# Create the figure and subplots
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(2.5, 1.78), gridspec_kw={'height_ratios': [omega_truncating_all['omega_trunc'].max(),
                                                                                    omega_missense_all['omega_mis'].max()
                                                                                   ]})

# Separate data based on significance of p-value
omega_truncating_sig = omega_truncating_all[omega_truncating_all["pvalue"] <= pvalue_thres].reset_index(drop = True)
omega_truncating_notsig = omega_truncating_all[omega_truncating_all["pvalue"] > pvalue_thres].reset_index(drop = True)

# Plot the second bar plot in the middle subplot
sns.barplot(data=omega_truncating_notsig, x='GENE', y='omega_trunc',
            ax=ax1, alpha=1,
            fill = False,
            hue = 'multi',
            hue_order = [False, True],
            # legend = False,
            order = gene_order,
            palette = {False : metrics_colors_dictionary["omega_trunc"],
                       True : metrics_colors_dictionary["omega_trunc"]
                      }
                       )


# Plot the second bar plot in the middle subplot
sns.barplot(data=omega_truncating_sig, x='GENE', y='omega_trunc',
            ax=ax1, alpha=1,
            legend = False,
            hue = 'multi',
            hue_order = [False, True],
            order = gene_order,
            palette = {False : metrics_colors_dictionary["omega_trunc"],
                       True : metrics_colors_dictionary["omega_trunc"]
                      },
            # color = metrics_colors_dictionary["omega_trunc"],
            edgecolor = None
           )

sns.barplot(data=omega_truncating_all[omega_truncating_all['multi'] == True], x='GENE', y='omega_trunc',
            ax=ax1, alpha=1,
            fill = False,
            hue = 'multi',
            hue_order = [False, True],
            order = gene_order,
            palette = {False : metrics_colors_dictionary["omega_trunc"],
                       True : 'black'
                      },
            dodge = True,
            edgecolor = 'black',
            hatch = "//////",
            linewidth = 0.5
           )


ax1.set_xlabel('')
ax1.set_ylabel('dN/dS\ntruncating',
                  #fontsize = 12,
                  rotation = 0, verticalalignment = 'center',
               horizontalalignment = 'right')
# ax1.set_yticks([0,10,20,30,40,50])
# ax1.set_yticklabels([0,10,20,30,40,50])
ax1.set_xticklabels([])  # Hide x-axis labels on the middle plot
ax1.axhline(1, color='black', linestyle='--')

# Remove top and right spines
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.legend(frameon = False)



# Separate data based on significance of p-value
omega_missense_sig = omega_missense_all[omega_missense_all["pvalue"] <= pvalue_thres].reset_index(drop = True)
omega_missense_notsig = omega_missense_all[omega_missense_all["pvalue"] > pvalue_thres].reset_index(drop = True)

# Plot the second bar plot in the middle subplot
sns.barplot(data=omega_missense_notsig, x='GENE', y='omega_mis',
            ax=ax2, alpha=1,
            fill = False,
            hue = 'multi',
            hue_order = [False, True],
            legend = False,
            order = gene_order,
            palette = {False : metrics_colors_dictionary["omega_miss"],
                       True : metrics_colors_dictionary["omega_miss"]
                      }
           )


# Plot the second bar plot in the middle subplot
sns.barplot(data=omega_missense_sig, x='GENE', y='omega_mis',
            ax=ax2, alpha=1,
            hue = 'multi',
            hue_order = [False, True],
            legend = False,
            order = gene_order,
            palette = {False : metrics_colors_dictionary["omega_miss"],
                       True : metrics_colors_dictionary["omega_miss"]
                      },
            edgecolor = None
           )



sns.barplot(data=omega_missense_all[omega_missense_all['multi'] == True], x='GENE', y='omega_mis',
            ax=ax2, alpha=1,
            fill = False,
            hue = 'multi',
            hue_order = [False, True],
            order = gene_order,
            palette = {False : metrics_colors_dictionary["omega_miss"],
                       True : 'black'
                      },
            legend = False,
            dodge = True,
            edgecolor = 'black',
            hatch = "//////",
            linewidth = 0.5
           )

ax2.set_xlabel('')
ax2.set_ylabel('dN/dS\nmissense',
                  #fontsize = 12,
                  rotation = 0, verticalalignment = 'center',
               horizontalalignment = 'right')
# ax2.set_yticks([0,3,6])
# ax2.set_yticklabels([0,3,6])

ax2.set_xticklabels([])  # Hide x-axis labels on the upper plot
ax2.axhline(1, color='black', linestyle='--')
# Remove top and right spines
ax2.spines['top'].set_visible(False)
ax2.spines['right'].set_visible(False)

ax2.set_xticks(range(len(gene_order)))
ax2.set_xticklabels(gene_order, rotation=90)



# Custom legend
legend_elements = [
    Patch(facecolor=metrics_colors_dictionary["omega_trunc"], edgecolor=None,
          # label="Expanded clones"
          label="Multiple mutations in\nthe same sample\naccounted only once"
         ),
    Patch(facecolor=metrics_colors_dictionary["omega_trunc"], edgecolor="black", hatch="//////",
          # label="Independent mutations"
          label="Multiple mutations in\nthe same sample\naccounted as many\ntimes as they are\nobserved",
          linewidth = 0.5
         )
]
ax1.legend(handles=legend_elements, frameon=False, loc="upper right")


plt.tight_layout()

plt.savefig(f"plots/ExtendedFig4f.pdf", bbox_inches='tight', dpi = 300)

plt.show()
